# %%
import pandas

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '.venv',
#  'addTwoNumbers.py',
#  'animalName.py',
#  'animalNameIsPython.py',
#  'conversion.py',
#  'goblin.py',
#  'height.py',
#  'journal-0.log',
#  'ladder.py',
#  'linesOfStars.py',
#  'rising.py',
#  'rollADouble.py',
#  'sleep.py',
#  'testing.ipynb']

# %%
df1 = pandas.read_json("http://pythonhow.com/supermarkets.json")
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1.set_index("ID")
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1.set_index("Address")
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1 = df1.sort_index()

# %%
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df2 = df1.sort_index(ascending=False)

# %%
df1 = pandas.read_json("http://pythonhow.com/supermarkets.json")
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
#
#               State
# 5          CA 94114
# 4        California
# 3          CA 94114
# 2  California 94114
# 1          CA 94119
# 0          CA 94114

# %%
df1 = df1.sort_index()
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1 = pandas.read_json("http://pythonhow.com/supermarkets.json")
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1.loc["735 Dolores St":"1056 Sanchez St","Employees":"Name"]
# Out:
# Empty DataFrame
# Columns: [Employees, ID, Name]
# Index: []

# %%
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1.set_index("Address")
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df1.loc["735 Dolores St":"1056 Sanchez St","Employees":"Name"]
# Out:
# Empty DataFrame
# Columns: [Employees, ID, Name]
# Index: []

# %%
df1.loc["735 Dolores St	" : "1056 Sanchez St"]
# Out:
# Empty DataFrame
# Columns: [Address, City, Country, Employees, ID, Name, State]
# Index: []

# %%
df1.loc["735 Dolores St":"1056 Sanchez St","Employees":"Name"]
# Out:
# Empty DataFrame
# Columns: [Employees, ID, Name]
# Index: []

# %%
df1 = pandas.read_json("http://pythonhow.com/supermarkets.json")
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1 = df1.set_index("Address")

# %%
df1.loc["735 Dolores St" : "332 Hill St", "Country":"ID"]
# Out:
#                Country  Employees  ID
# Address
# 735 Dolores St     USA         15   2
# 332 Hill St        USA         25   3

# %%
df1.loc[:,"Employees":"Name"]
# Out:
#                  Employees  ID         Name
# Address
# 3666 21st St             8   1      Madeira
# 735 Dolores St          15   2  Bready Shop
# 332 Hill St             25   3  Super River
# 3995 23rd St            10   4   Ben's Shop
# 1056 Sanchez St         12   5      Sanchez
# 551 Alvarado St         20   6   Richvalley

# %%
list(df1.loc[:,"Employees":"Name"])
# Out:
# ['Employees', 'ID', 'Name']

# %%
df1
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df1.iloc[1:4,3:5]
# Out:
#                 ID         Name
# Address
# 735 Dolores St   2  Bready Shop
# 332 Hill St      3  Super River
# 3995 23rd St     4   Ben's Shop

# %%
df1.iloc[1:5,3:6]
# Out:
#                  ID         Name             State
# Address
# 735 Dolores St    2  Bready Shop          CA 94119
# 332 Hill St       3  Super River  California 94114
# 3995 23rd St      4   Ben's Shop          CA 94114
# 1056 Sanchez St   5      Sanchez        California

# %%
df1.shape[0]
# Out:
# 6

# %%
df1.shape[1]
# Out:
# 6

# %%
df1.shape
# Out:
# (6, 6)

# %%
df1["Continent"]
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Jeff\source\repos\goblins\.venv\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Continent'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df1["Continent"]
#       2 df1
#
# ...

# %%
df1["Continent"].shape[0]="North America"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Jeff\source\repos\goblins\.venv\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Continent'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df1["Continent"].shape[0]="North America"
#
# ...

# %%
df1["Continent"].shape[0]=["North America"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Jeff\source\repos\goblins\.venv\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Continent'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df1["Continent"].shape[0]=["North America"]
#
# ...

# %%
df1["Continent"] = df1.shape[0]*["North America"]

# %%
df1
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State      Continent
# Address
# 3666 21st St             CA 94114  North America
# 735 Dolores St           CA 94119  North America
# 332 Hill St      California 94114  North America
# 3995 23rd St             CA 94114  North America
# 1056 Sanchez St        California  North America
# 551 Alvarado St          CA 94114  North America

# %%
df1["Continent"] = df1[["Country"] +", " + "North America"]]
# Out:
#   Cell In[59], line 1
#     df1["Continent"] = df1[["Country"] +", " + "North America"]]
#                                                                ^
# SyntaxError: unmatched ']'

# %%
df1["Continent"] = df1["Country"] +", " + "North America"

# %%
df1
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State           Continent
# Address
# 3666 21st St             CA 94114  USA, North America
# 735 Dolores St           CA 94119  USA, North America
# 332 Hill St      California 94114  USA, North America
# 3995 23rd St             CA 94114  USA, North America
# 1056 Sanchez St        California  USA, North America
# 551 Alvarado St          CA 94114  USA, North America

# %%
df1_t = df1.T

# %%
df1_t
# Out:
# Address          3666 21st St      735 Dolores St         332 Hill St  \
# City            San Francisco       San Francisco       San Francisco
# Country                   USA                 USA                 USA
# Employees                   8                  15                  25
# ID                          1                   2                   3
# Name                  Madeira         Bready Shop         Super River
# State                CA 94114            CA 94119    California 94114
# Continent  USA, North America  USA, North America  USA, North America
#
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# Country                   USA                 USA                 USA
# Employees                  10                  12                  20
# ID                          4                   5                   6
# ...

# %%
df1_t["My Address"] = ["My City", "My Country", 21, 7, "Rome", "Georgia 30161", "USA, North America"]

# %%
df1_t
# Out:
# Address          3666 21st St      735 Dolores St         332 Hill St  \
# City            San Francisco       San Francisco       San Francisco
# Country                   USA                 USA                 USA
# Employees                   8                  15                  25
# ID                          1                   2                   3
# Name                  Madeira         Bready Shop         Super River
# State                CA 94114            CA 94119    California 94114
# Continent  USA, North America  USA, North America  USA, North America
#
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St  \
# City            San Francisco       San Francisco       San Francisco
# Country                   USA                 USA                 USA
# Employees                  10                  12                  20
# ID                          4                   5                   6
# ...

# %%
df1_t = df1_t.T
dft_t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 df1_t = df1_t.T
# ----> 2 dft_t
#
# NameError: name 'dft_t' is not defined

# %%
df1_t
# Out:
#                           City     Country Employees ID         Name  \
# Address
# 3666 21st St     San Francisco         USA         8  1      Madeira
# 735 Dolores St   San Francisco         USA        15  2  Bready Shop
# 332 Hill St      San Francisco         USA        25  3  Super River
# 3995 23rd St     San Francisco         USA        10  4   Ben's Shop
# 1056 Sanchez St  San Francisco         USA        12  5      Sanchez
# 551 Alvarado St  San Francisco         USA        20  6   Richvalley
# My Address             My City  My Country        21  7         Rome
#
#                             State           Continent
# Address
# 3666 21st St             CA 94114  USA, North America
# 735 Dolores St           CA 94119  USA, North America
# 332 Hill St      California 94114  USA, North America
# 3995 23rd St             CA 94114  USA, North America
# 1056 Sanchez St        California  USA, North America
# 551 Alvarado St          CA 94114  USA, North America
# ...

# %%
df1_t["551 Alvarado St"] = ["My City", "My Country", 21, 7, "Rome", "Georgia 30161", "USA, North America"]

# %%
df1_t
# Out:
#                           City     Country Employees ID         Name  \
# Address
# 3666 21st St     San Francisco         USA         8  1      Madeira
# 735 Dolores St   San Francisco         USA        15  2  Bready Shop
# 332 Hill St      San Francisco         USA        25  3  Super River
# 3995 23rd St     San Francisco         USA        10  4   Ben's Shop
# 1056 Sanchez St  San Francisco         USA        12  5      Sanchez
# 551 Alvarado St  San Francisco         USA        20  6   Richvalley
# My Address             My City  My Country        21  7         Rome
#
#                             State           Continent     551 Alvarado St
# Address
# 3666 21st St             CA 94114  USA, North America             My City
# 735 Dolores St           CA 94119  USA, North America          My Country
# 332 Hill St      California 94114  USA, North America                  21
# 3995 23rd St             CA 94114  USA, North America                   7
# ...

# %%
df1_t = df1_t.T
dft_t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 2
#       1 df1_t = df1_t.T
# ----> 2 dft_t
#
# NameError: name 'dft_t' is not defined

# %%
df1_t
# Out:
# Address                3666 21st St      735 Dolores St         332 Hill St  \
# City                  San Francisco       San Francisco       San Francisco
# Country                         USA                 USA                 USA
# Employees                         8                  15                  25
# ID                                1                   2                   3
# Name                        Madeira         Bready Shop         Super River
# State                      CA 94114            CA 94119    California 94114
# Continent        USA, North America  USA, North America  USA, North America
# 551 Alvarado St             My City          My Country                  21
#
# Address                3995 23rd St     1056 Sanchez St     551 Alvarado St  \
# City                  San Francisco       San Francisco       San Francisco
# Country                         USA                 USA                 USA
# ...

# %%
df1_t["551 Alvarado St"] = ["My City", "My Country", 21, 7, "Rome", "Georgia 30161", "USA, North America"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df1_t["551 Alvarado St"] = ["My City", "My Country", 21, 7, "Rome", "Georgia 30161", "USA, North America"]
#
# File c:\Users\Jeff\source\repos\goblins\.venv\Lib\site-packages\pandas\core\frame.py:4091, in DataFrame.__setitem__(self, key, value)
#    4088     self._setitem_array([key], value)
#    4089 else:
#    4090     # set column
# -> 4091     self._set_item(key, value)
#
# File c:\Users\Jeff\source\repos\goblins\.venv\Lib\site-packages\pandas\core\frame.py:4300, in DataFrame._set_item(self, key, value)
#    4290 def _set_item(self, key, value) -> None:
#    4291     """
#    4292     Add series to DataFrame in specified column.
#    4293
#    (...)
#    4298     ensure homogeneity.
#    4299     """
# -> 4300     value, refs = self._sanitize_column(value)
#    4302     if (
# ...

# %%
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
import geopy
dir(geopy)
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'Geocodio',
#  'Geokeo',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'HereV7',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'What3WordsV3',
#  'Woosmap',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '__version_info__',
#  'adapters',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'get_version',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import Nominatim

# %%
nom = Nominatim()
nom.geocode("105 Mimosa Dr SE, Rome, GA 30161")
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 nom = Nominatim()
#       2 nom.geocode("105 Mimosa Dr SE, Rome, GA 30161")
#
# File c:\Users\Jeff\source\repos\goblins\.venv\Lib\site-packages\geopy\geocoders\nominatim.py:105, in Nominatim.__init__(self, timeout, proxies, domain, scheme, user_agent, ssl_context, adapter_factory)
#     101 self.domain = domain.strip('/')
#     103 if (self.domain == _DEFAULT_NOMINATIM_DOMAIN
#     104         and self.headers['User-Agent'] in _REJECTED_USER_AGENTS):
# --> 105     raise ConfigurationError(
#     106         'Using Nominatim with default or sample `user_agent` "%s" is '
#     107         'strongly discouraged, as it violates Nominatim\'s ToS '
#     108         'https://operations.osmfoundation.org/policies/nominatim/ '
#     109         'and may possibly cause 403 and 429 HTTP errors. '
# ...

# %%
nom = Nominatim(user_agent = "my_application")
n=nom.geocode("105 Mimosa Dr, Rome, GA 30161")

# %%
print(n)
# Out:
# 105, Mimosa Drive, Maplewood, Rome, Floyd County, Georgia, 30161, United States

# %%
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1["Address"] = df1["Address"] + ", " + df1["City"] + ", " + df1["State"] + ", " + df1["Country"]
df1
# Out:
#                                              Address           City Country  \
# 0         3666 21st St, San Francisco, CA 94114, USA  San Francisco     USA
# 1       735 Dolores St, San Francisco, CA 94119, USA  San Francisco     USA
# 2  332 Hill St, San Francisco, California 94114, USA  San Francisco     USA
# 3         3995 23rd St, San Francisco, CA 94114, USA  San Francisco     USA
# 4    1056 Sanchez St, San Francisco, California, USA  San Francisco     USA
# 5      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco     USA
#
#    Employees  ID         Name             State
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114

# %%
df1["Coordinates"]=df1["Address"].apply(nom.geocode)
df1
# Out:
#                                              Address           City Country  \
# 0         3666 21st St, San Francisco, CA 94114, USA  San Francisco     USA
# 1       735 Dolores St, San Francisco, CA 94119, USA  San Francisco     USA
# 2  332 Hill St, San Francisco, California 94114, USA  San Francisco     USA
# 3         3995 23rd St, San Francisco, CA 94114, USA  San Francisco     USA
# 4    1056 Sanchez St, San Francisco, California, USA  San Francisco     USA
# 5      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          Coordinates
# ...

# %%
df1["Coordinates"][2]
# Out:
# Location(332, Hill Street, Noe Valley, San Francisco, California, 94114, United States, (37.755836349999996, -122.42883158327517, 0.0))

# %%
df1
# Out:
#                                              Address           City Country  \
# 0         3666 21st St, San Francisco, CA 94114, USA  San Francisco     USA
# 1       735 Dolores St, San Francisco, CA 94119, USA  San Francisco     USA
# 2  332 Hill St, San Francisco, California 94114, USA  San Francisco     USA
# 3         3995 23rd St, San Francisco, CA 94114, USA  San Francisco     USA
# 4    1056 Sanchez St, San Francisco, California, USA  San Francisco     USA
# 5      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          Coordinates
# ...

# %%
df1["Latitude"]=df1["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df1
# Out:
#                                              Address           City Country  \
# 0         3666 21st St, San Francisco, CA 94114, USA  San Francisco     USA
# 1       735 Dolores St, San Francisco, CA 94119, USA  San Francisco     USA
# 2  332 Hill St, San Francisco, California 94114, USA  San Francisco     USA
# 3         3995 23rd St, San Francisco, CA 94114, USA  San Francisco     USA
# 4    1056 Sanchez St, San Francisco, California, USA  San Francisco     USA
# 5      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          Coordinates   Latitude
# ...

# %%
df1["Longitude"]=df1["Coordinates"].apply(lambda x: x.longitude if x != None else None)
df1
# Out:
#                                              Address           City Country  \
# 0         3666 21st St, San Francisco, CA 94114, USA  San Francisco     USA
# 1       735 Dolores St, San Francisco, CA 94119, USA  San Francisco     USA
# 2  332 Hill St, San Francisco, California 94114, USA  San Francisco     USA
# 3         3995 23rd St, San Francisco, CA 94114, USA  San Francisco     USA
# 4    1056 Sanchez St, San Francisco, California, USA  San Francisco     USA
# 5      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          Coordinates   Latitude   Longitude
# ...
